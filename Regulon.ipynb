# %%
import pandas as pd

# %%
df_operons = pd.read_table('data/Regulon/OperonSet.txt', comment='#', names=['name', 'l_pos', 'r_pos', 'strand', 'num_genes', 'blattner', 'evidence', 'level'])
df_tu = pd.read_table('data/Regulon/TUSet.txt', comment='#', names=['tu_id', 'tu_name', 'op_name', 'gene_name', 'pro_name', 'evidence', 'level'])
df_products = pd.read_table('data/Regulon/GeneProductSet.txt', comment='#', names=['gene_id', 'gene_ name', 'b_num', 'l_pos', 'r_pos', 'strand', 'product', 'evidence', 'PMID', 'level'])

df_operons = df_operons.loc[df_operons['level'].isin(['Strong', 'Confirmed'])]
df_tu = df_tu.loc[df_tu['level'].isin(['Strong', 'Confirmed'])]
df_products = df_products.loc[df_products['level'].isin(['Strong', 'Confirmed'])]

# %%
df_operons
# Out:
#                              name    l_pos    r_pos   strand  num_genes  \
# 17                           accA   208621   209580  forward          1
# 19                           accD  2433012  2433926  reverse          1
# 20                         aceBAK  4215478  4220332  forward          3
# 21                       ackA-pta  2413470  2416891  forward          2
# 28                          acrEF  3413864  3418137  forward          2
# 49                           agrA  3648063  3648146  forward          1
# 50                           agrB  3648294  3648377  forward          1
# 58                           alaS  2819381  2822011  reverse          1
# 60                           aldA  1488232  1489671  forward          1
# 71                      amiA-hemF  2552352  2554124  forward          2
# 79                      ansA-pncA  1850860  1852528  forward          2
# 83                        appCBXA  1037740  1041915  forward          4
# 86                           aqpZ   915352   916047  reverse          1
# 89                      araE-ygeA  2979943  2982182  reverse          2
# 93                           arcB  3350689  3353025  reverse          1
# 94                           arcZ  3350577  3350697  forward          1
# 95                           arfA  3438431  3438649  reverse          1
# 106                          argS  1960062  1961795  forward          1
# 110           argX-hisR-leuT-proM  3982375  3982811  forward          4
# 115   aroKB-damX-dam-rpe-gph-trpS  3512634  3519064  reverse          7
# 116                aroL-yaiA-aroM   406405   408105  forward          3
# 120                          arrS  3657986  3658054  reverse          1
# 121                        arsRBC  3648528  3650662  forward          3
# 132           asnC-mioC-mnmG-rsmG  3923057  3927003  reverse          4
# 134                          asnT  2044549  2044624  forward          1
# 135                          asnU  2059851  2059926  forward          1
# 136                          asnV  2062260  2062335  forward          1
# 137                          asnW  2058027  2058102  reverse          1
# 138                     aspA-dcuA  4365472  4368327  reverse          2
# 149                  atpIBEFHAGDC  3915553  3922440  reverse          9
# ...                           ...      ...      ...      ...        ...
# 1862                   ychQA-kdsA  1266924  1269019  forward          3
# 1936           ydgK-rsxABCDGE-nth  1705250  1712158  forward          8
# 1946                    ydhYVWXUT  1748747  1754477  reverse          6
# 1961               ydjA-selD-topB  1844999  1848676  reverse          3
# 1965                         ydjM  1810211  1810801  forward          1
# 2051                      yejABEF  2272364  2277889  forward          4
# 2119               yfiR-dgcN-yfiB  2741875  2744107  forward          3
# 2193                    ygiF-glnE  3196801  3200965  reverse          2
# 2215                        yhaOM  3255341  3258010  reverse          2
# 2234               yhdT-panF-prmA  3407375  3409951  forward          3
# 2240                         yhfA  3485414  3485818  reverse          1
# 2278                         yhjX  3710799  3712007  reverse          1
# 2285                         yiaJ  3741684  3742532  reverse          1
# 2286         yiaKLMNO-lyxK-sgbHUE  3742733  3750781  forward          9
# 2296          yibN-grxC-secB-gpsA  3782642  3785015  reverse          4
# 2304              yicR-rpmBG-mutM  3810343  3812559  reverse          4
# 2355                         yjaB  4213680  4214123  reverse          1
# 2358                         yjaZ  4189786  4190325  forward          1
# 2419              yjjB-dnaTC-yjjA  4599695  4602097  reverse          4
# 2422                         yjjP  4602088  4602858  reverse          1
# 2423                    yjjQ-bglJ  4603477  4604837  forward          2
# 2425                         yjjW  4614680  4615543  reverse          1
# 2438                        ykgMO   312374   312777  reverse          2
# 2439                         ykgR   313141   313242  reverse          1
# 2485                         yneM  1622646  1622741  forward          1
# 2550                     yqaE-kbp  2796337  2797028  reverse          2
# 2571                    yqhD-dkgA  3155355  3157450  forward          2
# 2589                         yrbL  3348452  3349084  forward          1
# 2592          yrdD-tsaC-aroE-yrdB  3429766  3431962  reverse          4
# 2620                         zinT  2041375  2042025  forward          1
#
#                                           blattner  \
# 17                                            accA
# 19                                            accD
# 20                                  aceB,aceA,aceK
# 21                                        ackA,pta
# 28                                       acrE,acrF
# 49                                            agrA
# 50                                            agrB
# 58                                            alaS
# 60                                            aldA
# 71                                       amiA,hemF
# 79                                       ansA,pncA
# 83                             appC,appB,appX,appA
# 86                                            aqpZ
# 89                                       araE,ygeA
# 93                                            arcB
# 94                                            arcZ
# 95                                            arfA
# 106                                           argS
# 110                            argX,hisR,leuT,proM
# 115                aroK,aroB,damX,dam,rpe,gph,trpS
# 116                                 aroL,yaiA,aroM
# 120                                           arrS
# 121                                 arsR,arsB,arsC
# 132                            asnC,mioC,mnmG,rsmG
# 134                                           asnT
# 135                                           asnU
# 136                                           asnV
# 137                                           asnW
# 138                                      aspA,dcuA
# 149   atpI,atpB,atpE,atpF,atpH,atpA,atpG,atpD,atpC
# ...                                            ...
# 1862                                ychQ,ychA,kdsA
# 1936        ydgK,rsxA,rsxB,rsxC,rsxD,rsxG,rsxE,nth
# 1946                 ydhY,ydhV,ydhW,ydhX,ydhU,ydhT
# 1961                                ydjA,selD,topB
# 1965                                          ydjM
# 2051                           yejA,yejB,yejE,yejF
# 2119                                yfiR,dgcN,yfiB
# 2193                                     ygiF,glnE
# 2215                                     yhaO,yhaM
# 2234                                yhdT,panF,prmA
# 2240                                          yhfA
# 2278                                          yhjX
# 2285                                          yiaJ
# 2286  yiaK,yiaL,yiaM,yiaN,yiaO,lyxK,sgbH,sgbU,sgbE
# 2296                           yibN,grxC,secB,gpsA
# 2304                           yicR,rpmB,rpmG,mutM
# 2355                                          yjaB
# 2358                                          yjaZ
# 2419                           yjjB,dnaT,dnaC,yjjA
# 2422                                          yjjP
# 2423                                     yjjQ,bglJ
# 2425                                          yjjW
# 2438                                     ykgM,ykgO
# 2439                                          ykgR
# 2485                                          yneM
# 2550                                      yqaE,kbp
# 2571                                     yqhD,dkgA
# 2589                                          yrbL
# 2592                           yrdD,tsaC,aroE,yrdB
# 2620                                          zinT
#
#                                                evidence      level
# 17    [LTED|S|Length of transcript experimentally de...     Strong
# 19    [LTED|S|Length of transcript experimentally de...     Strong
# 20    [BTEI|W|Boundaries of transcription experiment...     Strong
# 21    [LTED|S|Length of transcript experimentally de...     Strong
# 28    [LTED|S|Length of transcript experimentally de...     Strong
# 49    [LTED|S|Length of transcript experimentally de...     Strong
# 50    [LTED|S|Length of transcript experimentally de...     Strong
# 58    [LTED|S|Length of transcript experimentally de...     Strong
# 60    [LTED|S|Length of transcript experimentally de...     Strong
# 71    [LTED|S|Length of transcript experimentally de...     Strong
# 79                                [PM|S|Polar mutation]     Strong
# 83    [ITCR|W|Inferred through co-regulation],[PM|S|...     Strong
# 86    [LTED|S|Length of transcript experimentally de...     Strong
# 89    [LTED|S|Length of transcript experimentally de...     Strong
# 93    [LTED|S|Length of transcript experimentally de...     Strong
# 94    [LTED|S|Length of transcript experimentally de...     Strong
# 95    [LTED|S|Length of transcript experimentally de...     Strong
# 106   [LTED|S|Length of transcript experimentally de...     Strong
# 110   [LTED|S|Length of transcript experimentally de...     Strong
# 115                               [PM|S|Polar mutation]     Strong
# 116   [LTED|S|Length of transcript experimentally de...     Strong
# 120   [LTED|S|Length of transcript experimentally de...     Strong
# 121   [IHBCE|W|Inferred by a human based on computat...     Strong
# 132   [LTED|S|Length of transcript experimentally de...     Strong
# 134   [LTED|S|Length of transcript experimentally de...     Strong
# 135   [LTED|S|Length of transcript experimentally de...     Strong
# 136   [LTED|S|Length of transcript experimentally de...     Strong
# 137   [LTED|S|Length of transcript experimentally de...     Strong
# 138   [LTED|S|Length of transcript experimentally de...     Strong
# 149   [LTED|S|Length of transcript experimentally de...     Strong
# ...                                                 ...        ...
# 1862  [BTEI|W|Boundaries of transcription experiment...     Strong
# 1936  [LTED|S|Length of transcript experimentally de...     Strong
# 1946  [ICWHO|W|Inferred computationally without huma...     Strong
# 1961  [LTED|S|Length of transcript experimentally de...     Strong
# 1965  [LTED|S|Length of transcript experimentally de...     Strong
# 2051  [LTED|S|Length of transcript experimentally de...     Strong
# 2119  [ICWHO|W|Inferred computationally without huma...     Strong
# 2193  [LTED|S|Length of transcript experimentally de...     Strong
# 2215  [LTED|S|Length of transcript experimentally de...     Strong
# 2234  [BTEI|W|Boundaries of transcription experiment...     Strong
# 2240  [LTED|S|Length of transcript experimentally de...     Strong
# 2278  [LTED|S|Length of transcript experimentally de...     Strong
# 2285  [LTED|S|Length of transcript experimentally de...     Strong
# 2286  [LTED|S|Length of transcript experimentally de...  Confirmed
# 2296  [PM|S|Polar mutation]; [ICWHO|W|Inferred compu...     Strong
# 2304  [BTEI|W|Boundaries of transcription experiment...     Strong
# 2355  [LTED|S|Length of transcript experimentally de...     Strong
# 2358  [LTED|S|Length of transcript experimentally de...     Strong
# 2419  [LTED|S|Length of transcript experimentally de...     Strong
# 2422  [LTED|S|Length of transcript experimentally de...     Strong
# 2423  [LTED|S|Length of transcript experimentally de...     Strong
# 2425  [LTED|S|Length of transcript experimentally de...     Strong
# 2438  [LTED|S|Length of transcript experimentally de...     Strong
# 2439  [LTED|S|Length of transcript experimentally de...     Strong
# 2485  [LTED|S|Length of transcript experimentally de...     Strong
# 2550  [ICWHO|W|Inferred computationally without huma...     Strong
# 2571  [ICWHO|W|Inferred computationally without huma...     Strong
# 2589  [LTED|S|Length of transcript experimentally de...     Strong
# 2592  [LTED|S|Length of transcript experimentally de...  Confirmed
# 2620  [LTED|S|Length of transcript experimentally de...     Strong
#
# [348 rows x 8 columns]

# %%
df_tu
# Out:
#              tu_id      tu_name      op_name            gene_name pro_name  \
# 0     ECK120026560        C0067        C0067                C0067      NaN
# 1     ECK120026851        C0293        C0293                C0293      NaN
# 2     ECK120030224        C0299        C0299                C0299      NaN
# 3     ECK120030164        C0362        C0362                C0362      NaN
# 4     ECK120027910        C0465        C0465                C0465      NaN
# 5     ECK120027906        C0614        C0614                C0614      NaN
# 6     ECK120030163        C0664        C0664                C0664      NaN
# 7     ECK120027904        C0719        C0719                C0719      NaN
# 8     ECK120027339        IS128        IS128                IS128      NaN
# 9     ECK120021182         aaeR         aaeR                 aaeR    aaeRp
# 10    ECK120027580       aaeXAB       aaeXAB       aaeX,aaeA,aaeB    aaeXp
# 11    ECK120027435     aas-lplT     aas-lplT             aas,lplT      NaN
# 12    ECK120026783          aat          aat                  aat      NaN
# 13    ECK120026925   abgABT-ogt   abgABT-ogt   abgA,abgB,abgT,ogt      NaN
# 14    ECK125095214          ogt   abgABT-ogt                  ogt     ogtp
# 15    ECK120021183         abgR         abgR                 abgR      NaN
# 16    ECK120027376        abpAB        abpAB            abpA,abpB      NaN
# 17    ECK120026739         abrB         abrB                 abrB      NaN
# 18    ECK120009420         accA         accA                 accA    accAp
# 19    ECK125203406         accA         accA                 accA   accAp2
# 20    ECK120009421        accBC        accBC            accB,accC    accBp
# 21    ECK125203407        accBC        accBC            accB,accC   accBp2
# 22    ECK120009422         accD         accD                 accD    accDp
# 23    ECK120009194       aceBAK       aceBAK       aceB,aceA,aceK    aceBp
# 24    ECK120033577         aceK       aceBAK                 aceK    aceKp
# 25    ECK120009572         ackA     ackA-pta                 ackA    ackAp
# 26    ECK120015370     ackA-pta     ackA-pta             ackA,pta      NaN
# 27    ECK120015371          pta     ackA-pta                  pta      NaN
# 28    ECK120009826         acnA         acnA                 acnA   acnAp2
# 29    ECK120034134         acnA         acnA                 acnA   acnAp3
# ...            ...          ...          ...                  ...      ...
# 3523  ECK120021091         ytfB         ytfB                 ytfB    ytfBp
# 3524  ECK120016777         ytfE         ytfE                 ytfE    ytfEp
# 3525  ECK120027832         ytfF         ytfF                 ytfF      NaN
# 3526  ECK120021092         ytfH         ytfH                 ytfH      NaN
# 3527  ECK120027834         ytfI         ytfI                 ytfI      NaN
# 3528  ECK120009119         ytfJ         ytfJ                 ytfJ    ytfJp
# 3529  ECK120015507         ytfK         ytfK                 ytfK    ytfKp
# 3530  ECK120027835         ytfL         ytfL                 ytfL      NaN
# 3531  ECK120027837  ytfQRT-yjfF  ytfQRT-yjfF  ytfQ,ytfR,ytfT,yjfF      NaN
# 3532  ECK120027889         ytjA         ytjA                 ytjA      NaN
# 3533  ECK120009146    ytjB-lplA    ytjB-lplA            ytjB,lplA    ytjBp
# 3534  ECK120021093         ytjC         ytjC                 ytjC      NaN
# 3535  ECK120027717         yzcX         yzcX                 yzcX      NaN
# 3536  ECK120009185         yzfA         yzfA                 yzfA   yzfAp2
# 3537  ECK120027611         yzgL         yzgL                 yzgL      NaN
# 3538  ECK120027476         zapA         zapA                 zapA      NaN
# 3539  ECK120021037         zapB         zapB                 zapB      NaN
# 3540  ECK120026802         zapC         zapC                 zapC      NaN
# 3541  ECK120027575         zapE         zapE                 zapE      NaN
# 3542  ECK120015950         zinT         zinT                 zinT    zinTp
# 3543  ECK120027310         zipA         zipA                 zipA      NaN
# 3544  ECK120026746         zitB         zitB                 zitB      NaN
# 3545  ECK120009039         zntA         zntA                 zntA    zntAp
# 3546  ECK120009040         znuA         znuA                 znuA    znuAp
# 3547  ECK120009038        znuCB        znuCB            znuC,znuB    znuCp
# 3548  ECK120009821         zraP         zraP                 zraP    zraPp
# 3549  ECK120009822        zraSR        zraSR            zraS,zraR    zraSp
# 3550  ECK120021094         zupT         zupT                 zupT    zupTp
# 3551  ECK120021095          zur          zur                  zur      NaN
# 3552  ECK120009400          zwf          zwf                  zwf     zwfp
#
#                                                evidence   level
# 0     [ICWHO|W|Inferred computationally without huma...    Weak
# 1     [ICWHO|W|Inferred computationally without huma...    Weak
# 2                                                   NaN     NaN
# 3     [IHBCE|W|Inferred by a human based on computat...    Weak
# 4     [AISGDTU|W|Automated inference that a single-g...    Weak
# 5     [AISGDTU|W|Automated inference that a single-g...    Weak
# 6     [IHBCE|W|Inferred by a human based on computat...    Weak
# 7     [AISGDTU|W|Automated inference that a single-g...    Weak
# 8     [ICWHO|W|Inferred computationally without huma...    Weak
# 9     [AISGDTU|W|Automated inference that a single-g...    Weak
# 10    [ICWHO|W|Inferred computationally without huma...    Weak
# 11    [ICWHO|W|Inferred computationally without huma...    Weak
# 12    [ICWHO|W|Inferred computationally without huma...    Weak
# 13    [ICWHO|W|Inferred computationally without huma...    Weak
# 14                                                  NaN     NaN
# 15    [AISGDTU|W|Automated inference that a single-g...    Weak
# 16    [ICWHO|W|Inferred computationally without huma...    Weak
# 17    [ICWHO|W|Inferred computationally without huma...    Weak
# 18    [LTED|S|Length of transcript experimentally de...  Strong
# 19    [LTED|S|Length of transcript experimentally de...  Strong
# 20    [BTEI|W|Boundaries of transcription experiment...    Weak
# 21    [BTEI|W|Boundaries of transcription experiment...    Weak
# 22    [LTED|S|Length of transcript experimentally de...  Strong
# 23                                [PM|S|Polar mutation]  Strong
# 24    [BTEI|W|Boundaries of transcription experiment...    Weak
# 25                                                  NaN     NaN
# 26    [LTED|S|Length of transcript experimentally de...  Strong
# 27    [LTED|S|Length of transcript experimentally de...  Strong
# 28    [LTED|S|Length of transcript experimentally de...  Strong
# 29                           [IC|W|Inferred by curator]    Weak
# ...                                                 ...     ...
# 3523  [AISGDTU|W|Automated inference that a single-g...    Weak
# 3524  [IC|W|Inferred by curator],[BTEI|W|Boundaries ...    Weak
# 3525  [ICWHO|W|Inferred computationally without huma...    Weak
# 3526  [AISGDTU|W|Automated inference that a single-g...    Weak
# 3527  [ICWHO|W|Inferred computationally without huma...    Weak
# 3528  [BTEI|W|Boundaries of transcription experiment...    Weak
# 3529                                                NaN     NaN
# 3530  [ICWHO|W|Inferred computationally without huma...    Weak
# 3531  [ITCR|W|Inferred through co-regulation],[ICWHO...    Weak
# 3532  [ICWHO|W|Inferred computationally without huma...    Weak
# 3533  [ICWHO|W|Inferred computationally without huma...    Weak
# 3534  [AISGDTU|W|Automated inference that a single-g...    Weak
# 3535  [ICWHO|W|Inferred computationally without huma...    Weak
# 3536                                                NaN     NaN
# 3537  [ICWHO|W|Inferred computationally without huma...    Weak
# 3538  [ICWHO|W|Inferred computationally without huma...    Weak
# 3539  [AISGDTU|W|Automated inference that a single-g...    Weak
# 3540  [ICWHO|W|Inferred computationally without huma...    Weak
# 3541  [ICWHO|W|Inferred computationally without huma...    Weak
# 3542  [LTED|S|Length of transcript experimentally de...  Strong
# 3543  [ICWHO|W|Inferred computationally without huma...    Weak
# 3544  [ICWHO|W|Inferred computationally without huma...    Weak
# 3545                                                NaN     NaN
# 3546  [BTEI|W|Boundaries of transcription experiment...    Weak
# 3547  [BTEI|W|Boundaries of transcription experiment...    Weak
# 3548                                                NaN     NaN
# 3549  [ITCR|W|Inferred through co-regulation],[IEP|W...    Weak
# 3550  [AISGDTU|W|Automated inference that a single-g...    Weak
# 3551  [AISGDTU|W|Automated inference that a single-g...    Weak
# 3552                                                NaN     NaN
#
# [3553 rows x 7 columns]

# %%
df_products
# Out:
#            gene_id    gene_ name  b_num      l_pos      r_pos   strand  \
# 0     ECK120001251          thrL  b0001      190.0      255.0  forward
# 1     ECK120000987          thrA  b0002      337.0     2799.0  forward
# 2     ECK120000988          thrB  b0003     2801.0     3733.0  forward
# 3     ECK120000989          thrC  b0004     3734.0     5020.0  forward
# 4     ECK120002701          yaaX  b0005     5234.0     5530.0  forward
# 5     ECK120000009          yaaA  b0006     5683.0     6459.0  reverse
# 6     ECK120001508          yaaJ  b0007     6529.0     7959.0  reverse
# 7     ECK120001509          talB  b0008     8238.0     9191.0  forward
# 8     ECK120001467           mog  b0009     9306.0     9893.0  forward
# 9     ECK120001468          satP  b0010     9928.0    10494.0  reverse
# 10    ECK120002702          yaaW  b0011    10643.0    11356.0  reverse
# 11    ECK120001465          htgA  b0012    10830.0    11315.0  forward
# 12    ECK120004453          yaaI  b0013    11382.0    11786.0  reverse
# 13    ECK120000235          dnaK  b0014    12163.0    14079.0  forward
# 14    ECK120002604        tpke11    NaN    14080.0    14168.0  forward
# 15    ECK120000234          dnaJ  b0015    14168.0    15298.0  forward
# 16    ECK120002703        insL-1  b0016    15445.0    16557.0  forward
# 17    ECK120002704  Phantom Gene    NaN    15869.0    16177.0  reverse
# 18    ECK120002652          hokC  b4412    16751.0    16903.0  reverse
# 19    ECK120000366          mokC  b0018    16751.0    16960.0  reverse
# 20    ECK120002653          sokC  b4413    16952.0    17006.0  forward
# 21    ECK120000645          nhaA  b0019    17489.0    18655.0  forward
# 22    ECK120001066          nhaR  b0020    18715.0    19620.0  forward
# 23    ECK120023911       insAB-1    NaN    19811.0    20508.0  reverse
# 24    ECK120002705        insB-1  b0021    19811.0    20314.0  reverse
# 25    ECK120002706        insA-1  b0022    20233.0    20508.0  reverse
# 26    ECK120000910          rpsT  b0023    20815.0    21078.0  reverse
# 27    ECK120002707          yaaY  b0024    21181.0    21399.0  forward
# 28    ECK120001067          ribF  b0025    21407.0    22348.0  forward
# 29    ECK120000485          ileS  b0026    22391.0    25207.0  forward
# ...            ...           ...    ...        ...        ...      ...
# 4623  ECK120004444          yjjU  b4377  4612411.0  4613484.0  forward
# 4624  ECK120004445          yjjV  b4378  4613481.0  4614260.0  forward
# 4625  ECK120004446          yjjW  b4379  4614680.0  4615543.0  reverse
# 4626  ECK120002066          yjjI  b4380  4615515.0  4617065.0  reverse
# 4627  ECK120000215          deoC  b4381  4617323.0  4618102.0  forward
# 4628  ECK120000213          deoA  b4382  4618229.0  4619551.0  forward
# 4629  ECK120000214          deoB  b4383  4619603.0  4620826.0  forward
# 4630  ECK120000216          deoD  b4384  4620883.0  4621602.0  forward
# 4631  ECK120002217          yjjJ  b4385  4621769.0  4623100.0  forward
# 4632  ECK120001730          lplA  b4386  4623101.0  4624117.0  reverse
# 4633  ECK120000940          ytjB  b4387  4624145.0  4624789.0  reverse
# 4634  ECK120000934          serB  b4388  4624895.0  4625863.0  forward
# 4635  ECK120001269          radA  b4389  4625912.0  4627294.0  forward
# 4636  ECK120001306          nadR  b4390  4627315.0  4628547.0  forward
# 4637  ECK120002218          ettA  b4391  4628855.0  4630522.0  reverse
# 4638  ECK120000939           slt  b4392  4630733.0  4632670.0  forward
# 4639  ECK120001018          trpR  b4393  4632760.0  4633086.0  forward
# 4640  ECK120002327          yjjX  b4394  4633233.0  4633745.0  reverse
# 4641  ECK120002060          ytjC  b4395  4633797.0  4634444.0  forward
# 4642  ECK120001334           rob  b4396  4634441.0  4635310.0  reverse
# 4643  ECK120001196          creA  b4397  4635521.0  4635994.0  forward
# 4644  ECK120001197          creB  b4398  4636007.0  4636696.0  forward
# 4645  ECK120000721          creC  b4399  4636696.0  4638120.0  forward
# 4646  ECK120000141          creD  b4400  4638178.0  4639530.0  forward
# 4647  ECK120000057          arcA  b4401  4639590.0  4640306.0  reverse
# 4648  ECK120004447          yjjY  b4402  4640402.0  4640542.0  forward
# 4649  ECK120002186          yjtD  b4403  4640942.0  4641628.0  forward
# 4650  ECK120002630          alaB    NaN        NaN        NaN      NaN
# 4651  ECK120002677           dgd    NaN        NaN        NaN      NaN
# 4652  ECK120002672          ackB    NaN        NaN        NaN      NaN
#
#                                                 product  \
# 0                             thr operon leader peptide
# 1           aspartate kinase / homoserine dehydrogenase
# 2                                     homoserine kinase
# 3                                    threonine synthase
# 4                                     predicted protein
# 5     protein that reduces intracellular iron levels...
# 6                       putative transport protein YaaJ
# 7                                       transaldolase B
# 8                     molybdopterin adenylyltransferase
# 9           acetate / succinate:H<sup>+</sup> symporter
# 10                                    conserved protein
# 11      predicted DNA-binding transcriptional regulator
# 12                                    predicted protein
# 13                               chaperone protein DnaK
# 14                                               Tpke11
# 15                               chaperone protein DnaJ
# 16                              IS186/IS421 transposase
# 17                                                  NaN
# 18    HokC, Gef toxin; interferes with membrane func...
# 19    regulatory peptide whose translation enables h...
# 20                                                 SokC
# 21         Na<sup>+</sup>:H<sup>+</sup> antiporter NhaA
# 22                       NhaR transcriptional activator
# 23                                   InsAB' transposase
# 24                                     IS1 protein InsB
# 25                                     IS1 protein InsA
# 26                    30S ribosomal subunit protein S20
# 27                                    predicted protein
# 28    bifunctional riboflavin kinase / FMN adenylylt...
# 29                               isoleucine-tRNA ligase
# ...                                                 ...
# 4623                                 predicted esterase
# 4624                                    predicted DNase
# 4625  predicted pyruvate formate lyase activating en...
# 4626  conserved protein, may be involved in nitrogen...
# 4627                     deoxyribose-phosphate aldolase
# 4628     thymidine phosphorylase / uracil phosphorylase
# 4629                                 phosphopentomutase
# 4630                    purine nucleoside phosphorylase
# 4631    predicted DNA-binding transcriptional regulator
# 4632                           lipoate-protein ligase A
# 4633                                   membrane protein
# 4634                          phosphoserine phosphatase
# 4635                          DNA recombination protein
# 4636  NadR DNA-binding transcriptional repressor and...
# 4637    energy-dependent translational throttle protein
# 4638              soluble lytic murein transglycosylase
# 4639                     TrpR transcriptional repressor
# 4640                                      ITPase/XTPase
# 4641                              predicted phosphatase
# 4642     Rob DNA-binding transcriptional dual regulator
# 4643                                  conserved protein
# 4644                     CreB transcriptional regulator
# 4645                                               CreC
# 4646                   predicted inner membrane protein
# 4647                ArcA transcriptional dual regulator
# 4648                                  predicted protein
# 4649                   predicted rRNA methyltransferase
# 4650                glutamate-pyruvate aminotransferase
# 4651                        D-galactose 1-dehydrogenase
# 4652                                                NaN
#
#                                                evidence  \
# 0     [IDA|S|Inferred from direct assay],[IMP|W|Infe...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                [IMP|W|Inferred from mutant phenotype]
# 6     [AIFS|W|Automated inference of function from s...
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    [IGI|W|Inferred from genetic interaction],[IMP...
# 14                   [IDA|S|Inferred from direct assay]
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    [HIFS|W|Human inference of function from seque...
# 20    [IDA|S|Inferred from direct assay],[HIFS|W|Hum...
# 21                                                  NaN
# 22                                                  NaN
# 23               [IMP|W|Inferred from mutant phenotype]
# 24                                                  NaN
# 25               [IMP|W|Inferred from mutant phenotype]
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 4623                                                NaN
# 4624  [HIFS|W|Human inference of function from seque...
# 4625                                                NaN
# 4626  [IHBCE|W|Inferred by a human based on computat...
# 4627                                                NaN
# 4628                                                NaN
# 4629                                                NaN
# 4630                                                NaN
# 4631  [AIFS|W|Automated inference of function from s...
# 4632                                                NaN
# 4633                    [IE|W|Inferred from experiment]
# 4634                                                NaN
# 4635  [IGI|W|Inferred from genetic interaction],[IMP...
# 4636                                                NaN
# 4637  [IDA|S|Inferred from direct assay],[IMP|W|Infe...
# 4638                                                NaN
# 4639                                                NaN
# 4640                                                NaN
# 4641                                                NaN
# 4642                    [IE|W|Inferred from experiment]
# 4643                                                NaN
# 4644                                                NaN
# 4645                                                NaN
# 4646                                                NaN
# 4647  [GEA|W|Gene expression analysis],[APPH|S|Assay...
# 4648                                                NaN
# 4649                                                NaN
# 4650                                                NaN
# 4651                                                NaN
# 4652                                                NaN
#
#                                                    PMID   level
# 0                               3112412,318654,6811557,  Strong
# 1                                                   NaN     NaN
# 2                                                   NaN     NaN
# 3                                                   NaN     NaN
# 4                                             24391520,     NaN
# 5                                             21378183,    Weak
# 6                                             16397293,    Weak
# 7                                                   NaN     NaN
# 8                                                   NaN     NaN
# 9                                                   NaN     NaN
# 10                                                  NaN     NaN
# 11                                                  NaN     NaN
# 12                                            24391520,     NaN
# 13    10380927,10458167,10570141,19439666,21221969,2...  Strong
# 14                                            11553332,  Strong
# 15                               3003084,360036,360041,     NaN
# 16                                                  NaN     NaN
# 17                                                  NaN     NaN
# 18                                                  NaN     NaN
# 19                                            10361310,    Weak
# 20                                   10361310,15718303,  Strong
# 21    10398838,10671505,11275556,11697236,15236973,1...     NaN
# 22             1316901,1630901,2429258,3413113,8168494,     NaN
# 23                                             8083181,    Weak
# 24                                                  NaN     NaN
# 25                                             8083181,    Weak
# 26                                                  NaN     NaN
# 27                                                  NaN     NaN
# 28                                                  NaN     NaN
# 29            1329109,26070674,5324173,6390679,7629064,     NaN
# ...                                                 ...     ...
# 4623                                                NaN     NaN
# 4624                                          10747959,    Weak
# 4625                                                NaN     NaN
# 4626                                          22144874,    Weak
# 4627                                                NaN     NaN
# 4628                                                NaN     NaN
# 4629  10420269,10923257,11436549,11898608,12391882,1...     NaN
# 4630                                                NaN     NaN
# 4631                                          15556475,    Weak
# 4632        13549404,1765143,21209092,25303731,9445386,     NaN
# 4633                                                NaN    Weak
# 4634                                                NaN     NaN
# 4635         12446634,1327967,26845522,8759876,9141693,    Weak
# 4636                                                NaN     NaN
# 4637                24389465,24389466,24391520,9593292,  Strong
# 4638  10572120,11139297,12399477,2695826,3888619,698...     NaN
# 4639  1740124,1935980,2182120,2207078,3290685,360075...     NaN
# 4640                                                NaN     NaN
# 4641                                          21332126,     NaN
# 4642                                   7896685,8449900,    Weak
# 4643                                                NaN     NaN
# 4644           1482126,2157156,7699720,7855419,8098993,     NaN
# 4645                                           3531171,     NaN
# 4646                                                NaN     NaN
# 4647  12486057,1482126,16849788,2157156,2984198,7699...  Strong
# 4648                                                NaN     NaN
# 4649                                                NaN     NaN
# 4650                                    396446,4146872,     NaN
# 4651                                            181526,     NaN
# 4652                                                NaN     NaN
#
# [4653 rows x 10 columns]
